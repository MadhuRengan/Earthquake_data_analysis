# %%
import pymysql

# Connect to MySQL
conn = pymysql.connect(
    host='127.0.0.1',        # or your server IP
    user='root',
    password='madhu.1723',
    database='gst',
    port=3306                # default MySQL port
)

cursor = conn.cursor()

# %%
cursor.execute("select id,  mag, magType, type, Flag_based_on_mag from earthquake_data  order by mag desc limit 10;")
Strongest_earthquakes = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in Strongest_earthquakes:
    print(row)
# Out:
# ['id', 'mag', 'magType', 'type', 'Flag_based_on_mag']
# ('us6000qw60', 8.8, 'mww', 'earthquake', 'destructive')
# ('ak0219neiszm', 8.2, 'mww', 'earthquake', 'destructive')
# ('us6000f53e', 8.1, 'mww', 'earthquake', 'destructive')
# ('us7000dflf', 8.1, 'mww', 'earthquake', 'destructive')
# ('us7000qx2g', 7.8, 'mww', 'earthquake', 'destructive')
# ('us6000jllz', 7.8, 'mww', 'earthquake', 'destructive')
# ('us6000kd0n', 7.7, 'mww', 'earthquake', 'destructive')
# ('us7000pn9s', 7.7, 'mww', 'earthquake', 'destructive')
# ('us6000dg77', 7.7, 'mww', 'earthquake', 'destructive')
# ('us7000pcdl', 7.6, 'mww', 'earthquake', 'destructive')

# %%
cursor.execute("select id,  depth_km, type, Flag_based_on_depth from earthquake_data order by depth_km desc limit 10;")
Deepest_earthquakes = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in Deepest_earthquakes:
    print(row)
# Out:
# ['id', 'depth_km', 'type', 'Flag_based_on_depth']
# ('us6000sp3p', 683.578, 'earthquake', 'deep')
# ('us6000k2db', 681.238, 'earthquake', 'deep')
# ('us7000kxdn', 675.265, 'earthquake', 'deep')
# ('us6000mivr', 671.043, 'earthquake', 'deep')
# ('us6000rk66', 669.556, 'earthquake', 'deep')
# ('us6000f2w3', 669.46, 'earthquake', 'deep')
# ('us7000q1jk', 667.237, 'earthquake', 'deep')
# ('us7000s0st', 667.197, 'earthquake', 'deep')
# ('us6000dhfx', 664.74, 'earthquake', 'deep')
# ('us7000he64', 664.7, 'earthquake', 'deep')

# %%
cursor.execute("select id, mag,  depth_km, Flag_based_on_depth, type  from earthquake_data where depth_km<50 and mag >7.5 ;")
shallow_earthquakes = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in shallow_earthquakes:
    print(row)
# Out:
# ['id', 'mag', 'depth_km', 'Flag_based_on_depth', 'type']
# ('us6000dg77', 7.7, 10.0, 'shallow', 'earthquake')
# ('us7000dflf', 8.1, 28.93, 'shallow', 'earthquake')
# ('ak0219neiszm', 8.2, 35.0, 'shallow', 'earthquake')
# ('us6000f53e', 8.1, 22.79, 'shallow', 'earthquake')
# ('us7000i9bw', 7.6, 26.943, 'shallow', 'earthquake')
# ('us6000jllz', 7.8, 10.0, 'shallow', 'earthquake')
# ('us6000kd0n', 7.7, 18.053, 'shallow', 'earthquake')
# ('us7000lff4', 7.6, 40.0, 'shallow', 'earthquake')
# ('us7000pcdl', 7.6, 14.326, 'shallow', 'earthquake')
# ('us7000pn9s', 7.7, 10.0, 'shallow', 'earthquake')
# ('us6000qw60', 8.8, 35.0, 'shallow', 'earthquake')
# ('us7000qx2g', 7.8, 27.0, 'shallow', 'earthquake')
# ('us6000rgf4', 7.6, 5.639, 'shallow', 'earthquake')
# ('us6000rtdt', 7.6, 40.72, 'shallow', 'earthquake')

# %%
cursor.execute("select round(avg(depth_km),3) as avg_depth, place from earthquake_data group by place;")
depth_by_continents = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in depth_by_continents :

    print(row)
# Out:
# ['avg_depth', 'place']
# (163.498, 'Argentina')
# (538.934, 'Fiji region')
# (62.6, 'Philippines')
# (11.172, 'Iran')
# (9.981, 'Svalbard and Jan Mayen')
# (31.855, 'Puerto Rico')
# (30.027, 'India')
# (10.828, 'Guyana')
# (0.502, 'Wyoming')
# (72.87, 'Indonesia')
# (274.285, 'Wallis and Futuna')
# (34.042, 'South Sandwich Islands region')
# (88.636, 'Japan region')
# (518.927, 'Fiji')
# (73.586, 'Chile')
# (10.029, 'Carlsberg Ridge')
# (41.511, 'Alaska')
# (45.906, 'off the east coast of the North Island of New Zealand')
# (69.332, 'Dominican Republic')
# (102.115, 'Mariana Islands region')
# (93.542, 'Vanuatu')
# (452.24, 'south of the Fiji Islands')
# (10.035, 'Mid-Indian Ridge')
# (191.114, 'Timor Leste')
# (53.507, 'Solomon Islands')
# (10.0, 'Indian Ocean Triple Junction')
# (10.036, 'South Shetland Islands')
# (68.36, 'Kuril Islands')
# (68.287, 'Papua New Guinea')
# (10.0, 'southeast Indian Ridge')
# (10.0, 'Chagos Archipelago region')
# (6.637, 'New Mexico')
# ...

# %%
cursor.execute("select round(avg(mag),3) as avg_magnitude, magType from earthquake_data group by magType;")
avg_magnitude = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in avg_magnitude :

    print(row)
# Out:
# ['avg_magnitude', 'magType']
# (4.331, 'mwr')
# (4.424, 'mb')
# (3.441, 'md')
# (5.369, 'mww')
# (3.275, 'ml')
# (3.936, 'mw')
# (5.794, 'mwb')
# (3.205, 'mb_lg')
# (6.15, 'mwc')
# (3.48, 'mlr')
# (3.3, 'mlg')
# (5.8, 'ms_20')
# (3.469, 'mlv')
# (3.367, 'ml(texnet)')
# (4.6, 'ms_vx')
# (5.25, 'mwp')
# (4.1, 'mh')

# %%
cursor.execute("select Year, count(id) as earthquake_count from earthquake_data  group by year order by earthquake_count desc limit 1 ;")
Year_with_max_eq = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in Year_with_max_eq:

    print(row)
# Out:
# ['Year', 'earthquake_count']
# (2025, 22818)

# %%
cursor.execute(" select Month, count(id)as earthquake_count from earthquake_data  group by Month order by earthquake_count desc limit 1 ;")
Month_with_max_eq = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in Month_with_max_eq:

    print(row)
# Out:
# ['Month', 'earthquake_count']
# ('March', 10872)

# %%
cursor.execute(" select Day_of_week, count(id)as earthquake_count from earthquake_data group by Day_of_week order by earthquake_count desc limit 1 ;")
Day_with_max_eq = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in Day_with_max_eq:

    print(row)
# Out:
# ['Day_of_week', 'earthquake_count']
# ('Tuesday', 16212)

# %%
cursor.execute("select hour(time) as hour, count(id) as eq_count from earthquake_data  group by hour order by hour;")
eq_per_hr = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in eq_per_hr:

    print(row)
# Out:
# ['hour', 'eq_count']
# (0, 4639)
# (1, 4936)
# (2, 4759)
# (3, 4995)
# (4, 4942)
# (5, 4595)
# (6, 4520)
# (7, 4668)
# (8, 4658)
# (9, 4631)
# (10, 4491)
# (11, 4414)
# (12, 4371)
# (13, 4630)
# (14, 4482)
# (15, 4619)
# (16, 4525)
# (17, 4646)
# (18, 4703)
# (19, 4736)
# (20, 4759)
# (21, 4961)
# (22, 4844)
# (23, 4659)

# %%
cursor.execute("select count(net) as net_count, net from earthquake_data group by net order by net_count desc limit 1")
active_net = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in active_net:

    print(row)
# Out:
# ['net_count', 'net']
# (98084, 'us')

# %%
cursor.execute("select place, sum(felt) as casualties from earthquake_data group by place order by casualties desc limit 5 ")
highest_casualties = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in highest_casualties:

    print(row)
# Out:
# ['place', 'casualties']
# ('Alaska', 1285165.0)
# ('CA', 818262.0)
# ('Indonesia', 802365.0)
# ('Russia', 595854.0)
# ('Japan', 419370.0)

# %%
cursor.execute("select count(id) as count, status from earthquake_data  group by status ")
status_count = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in status_count:

    print(row)
# Out:
# ['count', 'status']
# (112011, 'reviewed')
# (172, 'automatic')

# %%
cursor.execute("select count(id) as count, type from earthquake_data  group by type ")
type_count = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in type_count:

    print(row)
# Out:
# ['count', 'type']
# (111337, 'earthquake')
# (803, 'mining explosion')
# (13, 'ice quake')
# (3, 'experimental explosion')
# (3, 'mine collapse')
# (2, 'quarry blast')
# (12, 'volcanic eruption')
# (4, 'landslide')
# (5, 'other event')
# (1, 'explosion')

# %%
cursor.execute("select count(id) as count, types from earthquake_data  group by types ")
types_count = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in types_count:

    print(row)
# Out:
# ['count', 'types']
# (1335, 'dyfi,moment-tensor,origin,phase-data')
# (85318, 'origin,phase-data')
# (8, 'dyfi,impact-text,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap')
# (8609, 'dyfi,origin,phase-data')
# (1345, 'moment-tensor,origin,phase-data')
# (236, 'dyfi,losspager,origin,phase-data,shakemap')
# (1035, 'dyfi,origin,phase-data,shakemap')
# (36, 'associate,origin,phase-data')
# (39, 'dyfi,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap')
# (461, 'losspager,origin,phase-data,shakemap')
# (262, 'dyfi,losspager,moment-tensor,origin,phase-data,shakemap')
# (493, 'dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link')
# (75, 'dyfi,impact-text,moment-tensor,origin,phase-data')
# (2120, 'origin,phase-data,shakemap')
# (15, 'dyfi,losspager,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shakemap')
# (186, 'dyfi,internal-moment-tensor,origin,phase-data')
# ...

# %%
cursor.execute("select round(avg(rms),3) as avg_rms, round(avg(gap),3) as avg_gap, place from earthquake_data group by place  ")
rms_gap = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in rms_gap:

    print(row)
# Out:
# ['avg_rms', 'avg_gap', 'place']
# (0.773, 80.326, 'Argentina')
# (0.663, 98.47, 'Fiji region')
# (0.7, 105.107, 'Philippines')
# (0.695, 94.943, 'Iran')
# (0.735, 74.443, 'Svalbard and Jan Mayen')
# (0.264, 230.831, 'Puerto Rico')
# (0.685, 104.321, 'India')
# (0.806, 78.111, 'Guyana')
# (0.623, 89.197, 'Wyoming')
# (0.718, 94.082, 'Indonesia')
# (0.711, 104.028, 'Wallis and Futuna')
# (0.679, 95.241, 'South Sandwich Islands region')
# (0.667, 108.649, 'Japan region')
# (0.662, 100.806, 'Fiji')
# (0.721, 106.08, 'Chile')
# (0.659, 103.408, 'Carlsberg Ridge')
# (0.631, 173.243, 'Alaska')
# (0.735, 162.227, 'off the east coast of the North Island of New Zealand')
# (0.433, 210.361, 'Dominican Republic')
# (0.643, 110.563, 'Mariana Islands region')
# (0.691, 119.664, 'Vanuatu')
# (0.719, 112.299, 'south of the Fiji Islands')
# (0.633, 81.653, 'Mid-Indian Ridge')
# (0.722, 78.618, 'Timor Leste')
# (0.658, 102.94, 'Solomon Islands')
# (0.64, 90.826, 'Indian Ocean Triple Junction')
# ...

# %% [markdown]
# nst threshold - greater than upper bound = q3 + 1.5 * iqr
# iqr = q3 - q1
# 75th percentile of nst is 46
# 25th percentile is 24
# iqr = 22
# upper boud = 46 + 1.5 * 22 = 79

# %%
cursor.execute("select id, nst , place , type from earthquake_data where nst > 79   ")
high_station_coverage = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in high_station_coverage:

    print(row)
# Out:
# ['id', 'nst', 'place', 'type']
# ('nc73514715', 112.0, 'CA', 'earthquake')
# ('ci39762912', 145.0, 'CA', 'earthquake')
# ('nc73512355', 153.0, 'CA', 'earthquake')
# ('nc73510910', 199.0, 'CA', 'earthquake')
# ('ci39510783', 84.0, 'CA', 'earthquake')
# ('ok2021edqa', 81.0, 'Oklahoma', 'earthquake')
# ('nc73529256', 100.0, 'CA', 'earthquake')
# ('nc73529196', 123.0, 'CA', 'earthquake')
# ('ci39803176', 110.0, 'CA', 'earthquake')
# ('nc73527826', 86.0, 'CA', 'earthquake')
# ('nc73526151', 164.0, 'CA', 'earthquake')
# ('ci39797144', 130.0, 'CA', 'earthquake')
# ('ok2021dmpg', 98.0, 'Oklahoma', 'earthquake')
# ('ci39546863', 92.0, 'CA', 'earthquake')
# ('nc73519926', 132.0, 'CA', 'earthquake')
# ('ok2021cony', 100.0, 'Oklahoma', 'earthquake')
# ('ok2021cnhw', 89.0, 'Oklahoma', 'earthquake')
# ('ok2021cnev', 101.0, 'Oklahoma', 'earthquake')
# ('nc73544470', 96.0, 'CA', 'earthquake')
# ('nc73541836', 80.0, 'CA', 'earthquake')
# ('nc73539551', 99.0, 'CA', 'earthquake')
# ...

# %%
cursor.execute("select year, count(tsunami) from earthquake_data where tsunami = 1 group by year  ")
tsunami_triggered = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in tsunami_triggered:

    print(row)
# Out:
# ['year', 'count(tsunami)']
# (2021, 114)
# (2022, 136)
# (2023, 119)
# (2024, 114)
# (2025, 142)
# (2026, 34)

# %%
cursor.execute("select alert, count(id) as count from earthquake_data group by alert  ")
alert = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in alert:

    print(row)
# Out:
# ['alert', 'count']
# ('green', 112009)
# ('yellow', 128)
# ('orange', 22)
# ('red', 24)

# %%
cursor.execute("select round(avg(mag),2) as mag_avg, place from earthquake_data group by place order by avg(mag) desc limit 5 ")
high_avg_mag = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in high_avg_mag:

    print(row)
# Out:
# ['mag_avg', 'place']
# (8.1, 'Russia Earthquake')
# (8.1, 'New Zealand Earthquake')
# (8.1, '2021 South Sandwich Islands Earthquake')
# (7.7, 'Burma (Myanmar) Earthquake')
# (7.57, 'Alaska Earthquake')

# %%
cursor.execute("select place, month from earthquake_data group by place, month  having sum(case when Flag_based_on_depth = 'shallow' then 1 else 0 end) > 1 and sum(case when Flag_based_on_depth = 'deep' then 1 else 0 end) > 1;")
shallow_deep = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in shallow_deep:

    print(row)
# Out:
# ['place', 'month']
# ('Argentina', 'January')
# ('Fiji region', 'January')
# ('Philippines', 'January')
# ('Puerto Rico', 'January')
# ('India', 'January')
# ('Indonesia', 'January')
# ('Wallis and Futuna', 'January')
# ('South Sandwich Islands region', 'January')
# ('Japan region', 'January')
# ('Fiji', 'January')
# ('Chile', 'January')
# ('Alaska', 'January')
# ('Dominican Republic', 'January')
# ('Mariana Islands region', 'January')
# ('Vanuatu', 'January')
# ('south of the Fiji Islands', 'January')
# ('Timor Leste', 'January')
# ('Solomon Islands', 'January')
# ('Kuril Islands', 'January')
# ('Papua New Guinea', 'January')
# ('Peru', 'January')
# ('Venezuela', 'January')
# ('El Salvador', 'January')
# ('Japan', 'January')
# ('Northern Mariana Islands', 'January')
# ('Guam', 'January')
# ('Ecuador', 'January')
# ('Colombia', 'January')
# ('Greece', 'January')
# ('Kermadec Islands region', 'January')
# ('Anguilla', 'January')
# ('Mona Passage', 'January')
# ('Russia', 'January')
# ...

# %%
cursor.execute("SELECT year, COUNT(id) AS event_count, ROUND((COUNT(id) - LAG(COUNT(id)) OVER (ORDER BY year)) / LAG(COUNT(id)) OVER (ORDER BY year) * 100, 2) AS growth_rate FROM earthquake_data GROUP BY year ORDER BY year;")
growth_rate = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in growth_rate:

    print(row)
# Out:
# ['year', 'event_count', 'growth_rate']
# (2021, 21926, None)
# (2022, 20208, Decimal('-7.84'))
# (2023, 20830, Decimal('3.08'))
# (2024, 18659, Decimal('-10.42'))
# (2025, 22818, Decimal('22.29'))
# (2026, 7742, Decimal('-66.07'))

# %%
cursor.execute("select place, round(avg(mag),2) as mag, count(id) as frequency, round(avg(mag)*count(id)) as sesmic_score from earthquake_data group by place order by sesmic_score desc limit 3;")
sesimic_score = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in sesimic_score:

    print(row)
# Out:
# ['place', 'mag', 'frequency', 'sesmic_score']
# ('Alaska', 3.47, 13684, 47512.0)
# ('Indonesia', 4.5, 8648, 38878.0)
# ('Russia', 4.48, 6139, 27523.0)

# %%
cursor.execute("select place, round(avg(depth_km),2) as avg_depth from earthquake_data where latitude >= -5 and latitude <=5 group by place ;")
latitude = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in latitude:

    print(row)
# Out:
# ['place', 'avg_depth']
# ('Philippines', 123.38)
# ('Guyana', 10.35)
# ('Indonesia', 62.42)
# ('Ecuador', 63.07)
# ('north of Ascension Island', 10.0)
# ('Colombia', 42.28)
# ('Celebes Sea', 452.79)
# ('Democratic Republic of the Congo', 9.92)
# ('Papua New Guinea', 72.77)
# ('Burundi', 10.0)
# ('Molucca Sea', 51.64)
# ('central East Pacific Rise', 10.0)
# ('Carlsberg Ridge', 10.04)
# ('south of Panama', 10.18)
# ('Peru', 64.2)
# ('central Mid-Atlantic Ridge', 10.01)
# ('off the coast of Central America', 10.28)
# ('Palau region', 15.09)
# ('Uganda', 10.08)
# ('Tanzania', 10.0)
# ('Gabon', 9.82)
# ('off the coast of Ecuador', 11.37)
# ('Galapagos Triple Junction region', 10.0)
# ('Chagos Archipelago region', 10.0)
# ('North Indian Ocean', 10.0)
# ('Brazil', 10.56)
# ('Banda Sea', 339.38)
# ('Rwanda', 10.44)
# ('west of the Galapagos Islands', 10.0)
# ('Kiribati region', 10.0)
# ('South Sudan', 10.0)
# ('off the west coast of northern Sumatra', 10.6)
# ('Panama', 10.0)
# ...

# %%
cursor.execute("select place,((sum(case when flag_based_on_depth = 'shallow' then 1 else 0 end))/nullif((sum(case when flag_based_on_depth = 'deep' then 1 else 0 end)),0)) as ratio  from earthquake_data group by place order by ratio desc limit 10 ;")
ratio = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in ratio:

    print(row)
# Out:
# ['place', 'ratio']
# ('Iran', Decimal('318.0000'))
# ('Canada', Decimal('281.0000'))
# ('Panama', Decimal('109.5000'))
# ('Nepal', Decimal('75.0000'))
# ('China', Decimal('70.7368'))
# ('Morocco', Decimal('65.0000'))
# ('Turkey', Decimal('59.5625'))
# ('Pakistan', Decimal('46.0000'))
# ('India region', Decimal('36.2500'))
# ('Cyprus', Decimal('36.0000'))

# %%
cursor.execute("select round(avg(case when tsunami = 0 then mag else null end),3) as avg_mag_no_tsunami, round(avg(case when tsunami = 1 then mag else null end),3) as avg_mag_tsunami ,round(( (avg(case when tsunami = 0 then mag else null end) )-( avg(case when tsunami = 1 then mag else null end))),3) as difference from earthquake_data ;")
tsunami = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in tsunami:

    print(row)
# Out:
# ['avg_mag_no_tsunami', 'avg_mag_tsunami', 'difference']
# (4.25, 5.416, -1.167)

# %%
cursor.execute("select id, place, gap , rms, 1.0 / (1 + (gap/180.0) + rms) AS reliability_score from earthquake_data order by reliability_score limit 10;")
lowest_reliable = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in lowest_reliable:

    print(row)
# Out:
# ['id', 'place', 'gap', 'rms', 'reliability_score']
# ('aka2026hogxjn', 'Alaska', 122.0, 3.4, 0.19693654266958427)
# ('ak2025xgbuwx', 'Alaska', 333.0, 1.83, 0.2136752136752137)
# ('us7000gc8r', 'Tonga', 122.0, 2.82, 0.2223320158102767)
# ('us7000dhvp', 'New Zealand', 289.0, 1.36, 0.2521714766040908)
# ('us6000r05v', 'Alaska', 341.0, 1.06, 0.2528800224782242)
# ('ci40332296', 'MX', 217.0, 1.71, 0.2553916004540295)
# ('us7000dinz', 'New Zealand', 299.0, 1.24, 0.25633722586157787)
# ('us6000p70f', 'Vanuatu', 283.0, 1.32, 0.2569226377390808)
# ('us7000p9s7', 'Alaska', 315.0, 1.13, 0.2577319587628866)
# ('us7000j0p2', 'Alaska', 327.0, 1.04, 0.2592912705272256)

# %%
cursor.execute("select * from (select id, time, latitude, longitude, lag(id) over (order by time) as prev_id, lag(time) over (order by time) as prev_time, lag(latitude) over (order by time) as prev_latitude, lag(longitude) over (order by time) as prev_longitude from earthquake_data) t having timestampdiff(minute, t.prev_time, t.time) <= 60 and abs(t.latitude - t.prev_latitude)<=0.5 and abs(t.longitude - t.prev_longitude)<=0.5;")
consecutive = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in consecutive:

    print(row)
# Out:
# ['id', 'time', 'latitude', 'longitude', 'prev_id', 'prev_time', 'prev_latitude', 'prev_longitude']
# ('us6000d7sa', datetime.datetime(2021, 1, 2, 9, 52, 39), -52.7852, 21.1438, 'us6000d7sw', datetime.datetime(2021, 1, 2, 9, 43, 39), -52.8326, 21.1548)
# ('us6000d7su', datetime.datetime(2021, 1, 2, 10, 3, 18), -52.7071, 21.3616, 'us6000d7sa', datetime.datetime(2021, 1, 2, 9, 52, 39), -52.7852, 21.1438)
# ('nc73506045', datetime.datetime(2021, 1, 2, 14, 42, 24), 36.6085, -121.2125, 'nc73506040', datetime.datetime(2021, 1, 2, 14, 36, 36), 36.6083333, -121.2156667)
# ('us6000d563', datetime.datetime(2021, 1, 3, 6, 42, 30), 25.88, 128.5499, 'us6000d80t', datetime.datetime(2021, 1, 3, 6, 11, 44), 25.817, 128.5092)
# ('ak02154bfwk', datetime.datetime(2021, 1, 3, 9, 58, 26), 66.6207, -147.8226, 'ak02154ber4', datetime.datetime(2021, 1, 3, 9, 58, 17), 66.6203, -147.9212)
# ...

# %%
cursor.execute("select place, count(id) as frequency from earthquake_data where depth_km>300 group by place order by frequency desc limit 10;")
deep_focus = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
print(columns)
for row in deep_focus:

    print(row)
# Out:
# ['place', 'frequency']
# ('south of the Fiji Islands', 1650)
# ('Fiji region', 1236)
# ('Fiji', 1188)
# ('Tonga', 598)
# ('Indonesia', 282)
# ('Japan region', 246)
# ('Timor Leste', 210)
# ('Wallis and Futuna', 162)
# ('Kermadec Islands region', 162)
# ('Northern Mariana Islands', 128)
